# %%
import os
import shutil
from tqdm.notebook import tqdm

# %%
dir = 'V:/pongsak/pico/0_fire'

# %%
files = os.listdir(dir+'/images')[9:]
files.sort()

# %%
files
# Out:
# ['pico_000173.jpg',
#  'pico_000174.jpg',
#  'pico_000175.jpg',
#  'pico_000176.jpg',
#  'pico_000177.jpg',
#  'pico_000178.jpg',
#  'pico_000179.jpg',
#  'pico_000180.jpg',
#  'pico_000181.jpg',
#  'pico_000182.jpg',
#  'pico_000183.jpg',
#  'pico_000184.jpg',
#  'pico_000185.jpg',
#  'pico_000186.jpg',
#  'pico_000187.jpg',
#  'pico_000188.jpg',
#  'pico_000189.jpg',
#  'pico_000190.jpg',
#  'pico_000191.jpg',
#  'pico_000192.jpg',
#  'pico_000193.jpg',
#  'pico_000194.jpg',
#  'pico_000195.jpg',
#  'pico_000196.jpg',
#  'pico_000197.jpg',
#  'pico_000198.jpg',
#  'pico_000199.jpg',
#  'pico_000200.jpg',
#  'pico_000201.jpg',
#  'pico_000202.jpg',
#  'pico_000203.jpg',
#  'pico_000204.jpg',
#  'pico_000205.jpg',
#  'pico_000206.jpg',
#  'pico_000207.jpg',
#  'pico_000208.jpg',
#  'pico_000209.jpg',
#  'pico_000210.jpg',
#  'pico_000211.jpg',
#  'pico_000212.jpg',
#  'pico_000213.jpg',
#  'pico_000214.jpg',
#  'pico_000215.jpg',
#  'pico_000216.jpg',
#  'pico_000217.jpg',
# ...

# %%
for f in tqdm(files):
    shutil.copyfile(f'{dir}/labels/pico_000172.txt', f'{dir}/labels/{f[:-3]}txt')
# Out:
#   0%|          | 0/453 [00:00<?, ?it/s]
